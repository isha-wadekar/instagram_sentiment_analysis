# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
d=pd.read_csv('/content/indianecoinsta.csv')#d is original data file
d=pd.DataFrame(d)
d[:2]
# Out:
#                                     postUrl  \
# 0  https://www.instagram.com/p/CtZHbixstuV/
# 1  https://www.instagram.com/p/Cs_PgtGpZbN/
#
#                                     profileUrl           username  \
# 0        https://www.instagram.com/investywise        investywise
# 1  https://www.instagram.com/barelyopinionated  barelyopinionated
#
#              fullName  commentCount  likeCount                   pubDate  \
# 0         InvestyWise            40       1742  2023-06-12T13:44:09.000Z
# 1  Barely Opinionated            97       4745  2023-06-02T12:34:30.000Z
#
#                                          description  \
# 0  Foreign direct equity investments declined by ...
# 1  What are your thoughts on this? 🤔\n\nSave & Sh...
#
#                                               imgUrl               postId  \
# 0  https://scontent-lhr8-1.cdninstagram.com/v/t51...  3123560495650626453
# 1  https://scontent-lhr8-1.cdninstagram.com/v/t51...  3116277685314492109
#
#        ownerId      type           query                 timestamp location  \
# 0  16190318992     Photo  #indianeconomy  2023-06-20T06:48:15.503Z      NaN
# 1  39209383554  Carousel  #indianeconomy  2023-06-20T06:48:15.503Z      NaN
#
#    isSidecar  sidecarMedias  viewCount videoUrl
# 0      False            NaN        NaN      NaN
# 1       True            2.0        NaN      NaN

# %%
d.shape
# Out:
# (9000, 19)

# %% [markdown]
# Data Exploration

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   postUrl        9000 non-null   object
#  1   profileUrl     9000 non-null   object
#  2   username       9000 non-null   object
#  3   fullName       8782 non-null   object
#  4   commentCount   9000 non-null   int64
#  5   likeCount      9000 non-null   int64
#  6   pubDate        9000 non-null   object
#  7   description    8991 non-null   object
#  8   imgUrl         8906 non-null   object
#  9   postId         9000 non-null   int64
#  10  ownerId        9000 non-null   int64
#  11  type           9000 non-null   object
#  12  query          9000 non-null   object
#  13  timestamp      9000 non-null   object
#  14  location       2174 non-null   object
#  15  isSidecar      9000 non-null   bool
#  16  sidecarMedias  1749 non-null   float64
#  17  viewCount      91 non-null     float64
#  18  videoUrl       94 non-null     object
# dtypes: bool(1), float64(2), int64(4), object(12)
# memory usage: 1.2+ MB

# %%
d.isnull().sum()
# Out:
# postUrl             0
# profileUrl          0
# username            0
# fullName          218
# commentCount        0
# likeCount           0
# pubDate             0
# description         9
# imgUrl             94
# postId              0
# ownerId             0
# type                0
# query               0
# timestamp           0
# location         6826
# isSidecar           0
# sidecarMedias    7251
# viewCount        8909
# videoUrl         8906
# dtype: int64

# %%
d.describe()
# Out:
#        commentCount      likeCount        postId       ownerId  sidecarMedias  \
# count   9000.000000    9000.000000  9.000000e+03  9.000000e+03    1749.000000
# mean       2.546556     211.037778  3.088897e+18  3.947005e+10       4.881075
# std       19.743168    2761.423937  2.440950e+16  2.068460e+10       2.570434
# min        0.000000       0.000000  2.833757e+18  6.329041e+06       2.000000
# 25%        0.000000       3.000000  3.066171e+18  1.619032e+10       3.000000
# 50%        0.000000       8.000000  3.088044e+18  4.898712e+10       4.000000
# 75%        1.000000      23.000000  3.111287e+18  5.669193e+10       7.000000
# max     1267.000000  214308.000000  3.129141e+18  6.048280e+10      10.000000
#
#           viewCount
# count     91.000000
# mean     252.615385
# std     1471.557624
# min        1.000000
# 25%        8.000000
# 50%       29.000000
# 75%       59.500000
# max    13841.000000

# %%
d['query'].value_counts()
# Out:
# #indianeconomy    9000
# Name: query, dtype: int64

# %%
d['type'].value_counts()
# Out:
# Photo       7157
# Carousel    1749
# Video         94
# Name: type, dtype: int64

# %% [markdown]
# Data Preprocessing

# %%
#d1 is the data for identification, source, type, post and its impressions
d1=d[['commentCount','likeCount','postId','ownerId','viewCount','description','type','pubDate','imgUrl']]
d1=d[['postId','ownerId','pubDate','type','description','imgUrl','viewCount','likeCount','commentCount']]
d1[:2]
# Out:
#                 postId      ownerId                   pubDate      type  \
# 0  3123560495650626453  16190318992  2023-06-12T13:44:09.000Z     Photo
# 1  3116277685314492109  39209383554  2023-06-02T12:34:30.000Z  Carousel
#
#                                          description  \
# 0  Foreign direct equity investments declined by ...
# 1  What are your thoughts on this? 🤔\n\nSave & Sh...
#
#                                               imgUrl  viewCount  likeCount  \
# 0  https://scontent-lhr8-1.cdninstagram.com/v/t51...        NaN       1742
# 1  https://scontent-lhr8-1.cdninstagram.com/v/t51...        NaN       4745
#
#    commentCount
# 0            40
# 1            97

# %%
d1.isnull().sum() #let's drop columns viewCount, imgUrl and rows where description is empty
# Out:
# postId             0
# ownerId            0
# pubDate            0
# type               0
# description        9
# imgUrl            94
# viewCount       8909
# likeCount          0
# commentCount       0
# dtype: int64

# %%
d2 = d1.dropna(subset=['description'])
d2.isnull().sum()
# Out:
# postId             0
# ownerId            0
# pubDate            0
# type               0
# description        0
# imgUrl            94
# viewCount       8900
# likeCount          0
# commentCount       0
# dtype: int64

# %%
d2.drop(['viewCount','imgUrl'],axis=1,inplace=True)
d2[:2]
# Out:
# <ipython-input-41-f34beead1dc6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2.drop(['viewCount','imgUrl'],axis=1,inplace=True)
#                 postId      ownerId                   pubDate      type  \
# 0  3123560495650626453  16190318992  2023-06-12T13:44:09.000Z     Photo
# 1  3116277685314492109  39209383554  2023-06-02T12:34:30.000Z  Carousel
#
#                                          description  likeCount  commentCount
# 0  Foreign direct equity investments declined by ...       1742            40
# 1  What are your thoughts on this? 🤔\n\nSave & Sh...       4745            97

# %%
d2.isnull().sum()
# Out:
# postId          0
# ownerId         0
# pubDate         0
# type            0
# description     0
# likeCount       0
# commentCount    0
# dtype: int64

# %% [markdown]
# Data Analysis

# %%
from textblob import TextBlob
d2['Subjectivity'] = d2['description'].apply(lambda x: TextBlob(x).sentiment.subjectivity)
d2['Polarity'] = d2['description'].apply(lambda x: TextBlob(x).sentiment.polarity)
d2['Sentiment'] = d2['Polarity'].apply(lambda x: 'negative' if x<0 else 'positive' if x>0 else 'neutral')
d2[:2]
# Out:
# <ipython-input-45-eb048439f634>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2['Subjectivity'] = d2['description'].apply(lambda x: TextBlob(x).sentiment.subjectivity)
# <ipython-input-45-eb048439f634>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2['Polarity'] = d2['description'].apply(lambda x: TextBlob(x).sentiment.polarity)
# <ipython-input-45-eb048439f634>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2['Sentiment'] = d2['Polarity'].apply(lambda x: 'negative' if x<0 else 'positive' if x>0 else 'neutral')
#                 postId      ownerId                   pubDate      type  \
# 0  3123560495650626453  16190318992  2023-06-12T13:44:09.000Z     Photo
# 1  3116277685314492109  39209383554  2023-06-02T12:34:30.000Z  Carousel
#
#                                          description  likeCount  commentCount  \
# 0  Foreign direct equity investments declined by ...       1742            40
# 1  What are your thoughts on this? 🤔\n\nSave & Sh...       4745            97
#
#    Subjectivity  Polarity Sentiment
# 0        0.2625   -0.0125  negative
# 1        0.0000    0.0000   neutral

# %%
d2.describe()#aggregate sentiment is 'a bit positive'
# Out:
#              postId       ownerId      likeCount  commentCount  Subjectivity  \
# count  8.991000e+03  8.991000e+03    8991.000000   8991.000000   8991.000000
# mean   3.088910e+18  3.946419e+10     211.232121      2.548104      0.295404
# std    2.439446e+16  2.069217e+10    2762.798929     19.752988      0.245283
# min    2.833757e+18  6.329041e+06       0.000000      0.000000      0.000000
# 25%    3.066200e+18  1.611518e+10       3.000000      0.000000      0.000000
# 50%    3.088061e+18  4.896248e+10       8.000000      0.000000      0.309504
# 75%    3.111277e+18  5.669193e+10      23.000000      1.000000      0.474309
# max    3.129141e+18  6.048280e+10  214308.000000   1267.000000      1.000000
#
#           Polarity
# count  8991.000000
# mean      0.130369
# std       0.181201
# min      -1.000000
# 25%       0.000000
# 50%       0.091667
# 75%       0.220000
# max       1.000000

# %% [markdown]
# Data analysis of posts that got liked atleast n times

# %%
def polarity(data,n):
  from textblob import TextBlob
  for i in range(len(data)):
    if data[i]['likeCount']>=n:
      data[i]['Polarity']=data['description'].apply(lambda x: TextBlob(x).sentiment.polarity)
  return data

# %%
def subjectivity(data,n):
  from textblob import TextBlob
  for i in range(len(data)):
    if data[i]['likeCount']>=n:
      data[i]['Subjectivity']=data['description'].apply(lambda x: TextBlob(x).sentiment.subjectivity)
  return data

# %%
polarity(d2,211)

# %%
subjectivity(d2,211)
